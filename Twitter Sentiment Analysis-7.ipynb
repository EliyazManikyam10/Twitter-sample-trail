# %%
# !pip install tweet-preprocessor
# Out:
# Requirement already satisfied: tweet-preprocessor in /Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages (0.6.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Users/lakshmipriya/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/cd/82/04e9aaf603fdbaecb4323b9e723f13c92c245f6ab2902195c53987848c78/pip-21.1.2-py3-none-any.whl (1.5MB)
#     100% |████████████████████████████████| 1.6MB 1.9MB/s ta 0:00:01
# Installing collected packages: pip
#   Found existing installation: pip 19.0.3
#     Uninstalling pip-19.0.3:
#       Successfully uninstalled pip-19.0.3
# Successfully installed pip-21.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install preprocessor
# Out:
# Collecting preprocessor
#   Downloading preprocessor-1.1.3.tar.gz (4.2 kB)
# Building wheels for collected packages: preprocessor
#   Building wheel for preprocessor (setup.py) ... done
#   Created wheel for preprocessor: filename=preprocessor-1.1.3-py3-none-any.whl size=4475 sha256=25ca5df7b2673131cbe5479e83584435b33c6991546227cb50d6c72f95c905f2
#   Stored in directory: /Users/lakshmipriya/Library/Caches/pip/wheels/e4/4e/bf/0ecf68aa10ee89d684d90437bd9f89ac19d5dc2921988bb59d
# Successfully built preprocessor
# Installing collected packages: preprocessor
# Successfully installed preprocessor-1.1.3
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Users/lakshmipriya/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
pip install -i https://pypi.anaconda.org/berber/simple tweet-preprocessor
# Out:
# Looking in indexes: https://pypi.anaconda.org/berber/simple
# Collecting tweet-preprocessor
#   Downloading https://pypi.anaconda.org/berber/simple/tweet-preprocessor/0.5.0/tweet-preprocessor-0.5.0.tar.gz (6.3 kB)
# Building wheels for collected packages: tweet-preprocessor
#   Building wheel for tweet-preprocessor (setup.py) ... done
#   Created wheel for tweet-preprocessor: filename=tweet_preprocessor-0.5.0-py3-none-any.whl size=8056 sha256=2291be457abf6ecff092fe1b62618f0f8f7ac8464e515526d38dded690ce2672
#   Stored in directory: /Users/lakshmipriya/Library/Caches/pip/wheels/48/f1/31/ebaa02d758e7936964301dcdd2063947b534dc1f78fdb7bf4d
# Successfully built tweet-preprocessor
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#import required libraries
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
import preprocessor as p

# %%
#import data
train = pd.read_csv('train_E6oV3lV.csv')
test = pd.read_csv('test_tweets_anuFYb8.csv')

# %%
#eda
train
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# 5          6      0  [2/2] huge fan fare and big talking before the...
# 6          7      0   @user camping tomorrow @user @user @user @use...
# 7          8      0  the next school year is the year for exams.ð...
# 8          9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9         10      0   @user @user welcome here !  i'm   it's so #gr...
# 10        11      0   â #ireland consumer price index (mom) climb...
# 11        12      0  we are so selfish. #orlando #standwithorlando ...
# 12        13      0  i get to see my daddy today!!   #80days #getti...
# 13        14      1  @user #cnn calls #michigan middle school 'buil...
# 14        15      1  no comment!  in #australia   #opkillingbay #se...
# 15        16      0  ouch...junior is angryð#got7 #junior #yugyo...
# 16        17      0  i am thankful for having a paner. #thankful #p...
# 17        18      1                             retweet if you agree!
# 18        19      0  its #friday! ð smiles all around via ig use...
# 19        20      0  as we all know, essential oils are not made of...
# 20        21      0  #euro2016 people blaming ha for conceded goal ...
sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
#data cleaning
#set up special charecters/punctuations we want to be replaced using regular expression
re_without_space = re.compile("(\.)|(\,)|(\{)|(\})|(\()|(\))|(\[)|(\])|(\;)|(\:)|(\!)|(\`)|(\')|(\")|(\%)|(\$)|(\<)|(\>)|(\?)|(\|)|")
re_with_space = re.compile("(<br\s/><br\s/?)|(-)|(/)|(:).")

# %%
#defining a function to clean the dataset using tweet preprocessor and re
def cleantweet(tweet):
        temp = p.clean(tweet)
        temp = re_without_space.sub('', temp.lower())
        temp = re_with_space.sub(' ', temp)
        return temp

# %%
#cleaning the train and test datasets
train['clean'] = train['tweet'].apply(cleantweet)
test['clean'] = test['tweet'].apply(cleantweet)

# %%
train
# Out:
#           id  label                                              tweet  \
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# 5          6      0  [2/2] huge fan fare and big talking before the...
# 6          7      0   @user camping tomorrow @user @user @user @use...
# 7          8      0  the next school year is the year for exams.ð...
# 8          9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9         10      0   @user @user welcome here !  i'm   it's so #gr...
# 10        11      0   â #ireland consumer price index (mom) climb...
# 11        12      0  we are so selfish. #orlando #standwithorlando ...
# 12        13      0  i get to see my daddy today!!   #80days #getti...
# 13        14      1  @user #cnn calls #michigan middle school 'buil...
# 14        15      1  no comment!  in #australia   #opkillingbay #se...
# 15        16      0  ouch...junior is angryð#got7 #junior #yugyo...
# 16        17      0  i am thankful for having a paner. #thankful #p...
# 17        18      1                             retweet if you agree!
# 18        19      0  its #friday! ð smiles all around via ig use...
# 19        20      0  as we all know, essential oils are not made of...
# 20        21      0  #euro2016 people blaming ha for conceded goal ...
# 21        22      0  sad little dude..   #badday #coneofshame #cats...
# 22        23      0  product of the day: happy man #wine tool  who'...
# 23        24      1    @user @user lumpy says i am a . prove it lumpy.
# 24        25      0   @user #tgif   #ff to my #gamedev #indiedev #i...
# 25        26      0  beautiful sign by vendor 80 for $45.00!! #upsi...
# 26        27      0   @user all #smiles when #media is   !! ðð...
# 27        28      0  we had a great panel on the mediatization of t...
# 28        29      0        happy father's day @user ðððð
# 29        30      0  50 people went to nightclub to have a good nig...
# ...      ...    ...                                                ...
# 31932  31933      0                               @user thanks gemma
# 31933  31934      1  @user judd is a  &amp; #homophobic #freemilo #...
# 31934  31935      1  lady banned from kentucky mall. @user  #jcpenn...
# 31935  31936      0  ugh i'm trying to enjoy my happy hour drink &a...
# 31936  31937      0  want to know how to live a   life? do more thi...
# 31937  31938      0                                 love island ð
# 31938  31939      0  my fav actor #vijaysethupathi ! my fav actress...
# 31939  31940      0      whew  ð
#  it's a productive and   #friday!!!
# 31940  31941      0                 @user she's finally here! @user
# 31941  31942      0  passed first year of uni #yay #love #pass #uni...
# 31942  31943      0  this week is flying by   #humpday - #wednesday...
# 31943  31944      0   @user modeling photoshoot this friday yay #mo...
# 31944  31945      0  you're surrounded by people who love you (even...
# 31945  31946      0  feel like... ðð¶ð #dog #summer #hot #h...
# 31946  31947      1  @user omfg i'm offended! i'm a  mailbox and i'...
# 31947  31948      1  @user @user you don't have the balls to hashta...
# 31948  31949      1   makes you ask yourself, who am i? then am i a...
# 31949  31950      0  hear one of my new songs! don't go - katie ell...
# 31950  31951      0   @user you can try to 'tail' us to stop, 'butt...
# 31951  31952      0  i've just posted a new blog: #secondlife #lone...
# 31952  31953      0                @user you went too far with @user
# 31953  31954      0  good morning #instagram #shower #water #berlin...
# 31954  31955      0  #holiday   bull up: you will dominate your bul...
# 31955  31956      0  less than 2 weeks ð
# ðð¼ð¹ððµ @us...
# 31956  31957      0  off fishing tomorrow @user carnt wait first ti...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
#                                                    clean
# 0      when a father is dysfunctional and is so selfi...
# 1      thanks for credit i cant use cause they dont o...
# 2                                    bihday your majesty
# 3      i love u take with u all the time in urð± ð...
# 4                                 factsguide society now
# 5      2 2 huge fan fare and big talking before they ...
# 6                              camping tomorrow dannyâ¦
# 7      the next school year is the year for examsð¯...
# 8                               we won love the land â¦
# 9                               welcome here  im its so
# 10     â consumer price index mom climbed from prev...
# 11                                     we are so selfish
# 12                           i get to see my daddy today
# 13             calls middle school build the wall chant
# 14                                         no comment in
# 15                               ouchjunior is angryð
# 16                      i am thankful for having a paner
# 17                                  retweet if you agree
# 18     its  ð smiles all around via ig user make p...
# 19     as we all know essential oils are not made of ...
# 20     people blaming ha for conceded goal was it fat...
# 21                                       sad little dude
# 22     product of the day happy man tool whos its the...
# 23                     lumpy says i am a  prove it lumpy
# 24                                                to my
# 25                     beautiful sign by vendor for 4500
# 26     all when is  ðð in  sunday love ðð...
# 27     we had a great panel on the mediatization of t...
# 28                    happy fathers day ðððð
# 29     people went to nightclub to have a good night ...
# ...                                                  ...
# 31932                                       thanks gemma
# 31933                                     judd is a &amp
# 31934                     lady banned from kentucky mall
# 31935  ugh im trying to enjoy my happy hour drink &am...
# 31936  want to know how to live a life do more things...
# 31937                                   love island ð
# 31938  my fav actor  my fav actress  my most fav dire...
# 31939                     whew ð its a productive and
# 31940                                  shes finally here
# 31941                           passed first year of uni
# 31942                        this week is flying by   ¦
# 31943                modeling photoshoot this friday yay
# 31944  youre surrounded by people who love you even m...
# 31945                             feel like ðð¶ð
# 31946         omfg im offended im a mailbox and im proud
# 31947  you dont have the balls to hashtag me as a but...
# 31948  makes you ask yourself who am i then am i anyb...
# 31949     hear one of my new songs dont go   katie ellie
# 31950  you can try to tail us to stop butt were just ...
# 31951                         ive just posted a new blog
# 31952                              you went too far with
# 31953                                       good morning
# 31954  bull up you will dominate your bull and you wi...
# 31955           less than weeks ð ðð¼ð¹ððµ
# 31956  off fishing tomorrow carnt wait first time in ...
# 31957  ate isz that youuuððððððð...
# 31958  to see nina turner on the airwaves trying to w...
# 31959  listening to sad songs on a monday morning otw...
# 31960                     vandalised in in  condemns act
# 31961                           thank you for you follow
#
# [31962 rows x 4 columns]

# %%
label=train.pop('label')

# %%
label.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
train_02=train.drop('tweet',axis=1)
`

# %%
test_02 = test.drop('tweet',axis=1)

# %%
test_02
# Out:
#           id                                              clean
# 0      31963                                         to find ¦
# 1      31964  want everyone to see the new â  â and he...
# 2      31965                           safe ways to heal your
# 3      31966  is the hp and the cursed child book up for res...
# 4      31967  rd to my amazing hilarious eli ahmir uncle dav...
# 5      31968                                       choose to be
# 6      31969  something inside me dies ð¦ð¿â¨ eyes ness ¦
# 7      31970                     ¤ï¸ ¤ï¸â¤ï¸â¤ï¸â¤ï¸
# 8      31971  i will never understand why my dad left me whe...
# 9      31972                                    mannaepicure ¦
# 10     31973  dayswasted   narcosis infinite ep make me awar...
# 11     31974           one of the worlds greatest spoing events
# 12     31975          half way through the website now and very
# 13     31976  good food good life  and ðððððð...
# 14     31977                              ill stand behind this
# 15     31978                       i atei ate and i ateðð
# 16     31979    got my limited edition rain or shine set today
# 17     31980                &amp &amp &amp too how to keep your
# 18     31981                 ð­ðð london united kingdom
# 19     31982  thought factory bbc neutrality on right wing f...
# 20     31983  hey guys tommorow is the last day of my exams ...
# 21     31984                        memoriesð­â¤ðð«ð
# 22     31985  my mind is like ððð½ð but my body l...
# 23     31986   never been this down on myself in my entire life
# 24     31987  check twitterww   trends trending worldwide 14...
# 25     31988                      i thought i saw a mermaid â¦
# 26     31989               chick gets fucked hottest naked lady
# 27     31990                       happy bday lucyâ¨â¨ð ¦
# 28     31991  haroldfriday have a weekend filled with sunbea...
# 29     31992  tried that but nothing   will try again know y...
# ...      ...                                                ...
# 17167  49130  people do anything for fucking attention nowad...
# 17168  49131  creative bubble got burst ð¢ looking forward...
# 17169  49132  tomorrow is gonna be a big day we are going to...
# 17170  49133                     i am thankful for baby giggles
# 17171  49134  i love u take with u all the time in urð± ð...
# 17172  49135  in life u will grow to learn some pple will wo...
# 17173  49136  ði was the stormyou were the rain together ...
# 17174  49137                            lovelgq   broken ep via
# 17175  49138      spread love not hateâ¤ï¸ðððð ¦
# 17176  49139                       are the most racist pay ever
# 17177  49140                         i am thankful for children
# 17178  49141                        liverpool â¤ï¸ð¬ð§ ¦
# 17179  49142  rooster simulation i want to climb the vast ea...
# 17180  49143                             por do sol ó¾â¤ï¸
# 17181  49144  hell yeah what a great surprise for your prese...
# 17182  49145  when ur the joke ur defensive towards everythi...
# 17183  49146                      the in my â¨ evening ð ¦
# 17184  49147  tonight on from pm gmt you can here a special ...
# 17185  49148                  today is a good day for excercise
# 17186  49149  good night with a tea and music âï¸ðð...
# 17187  49150  loving lifeðºð¸âï¸ð hyatt regency lo...
# 17188  49151  black professor demonizes proposes nazi style ...
# 17189  49152                        learn how to think positive
# 17190  49153             we love the pretty happy and fresh you
# 17191  49154  _damn_tuff ruff_muff__techno_city ng005 web 19...
# 17192  49155       thought factory left right polarisation &gt3
# 17193  49156                    feeling like a mermaid ð â¦
# 17194  49157  today in omg &amp used words like assets&ampli...
# 17195  49158  happy at work conference right mindset leads t...
# 17196  49159                      my song so glad free download
#
# [17197 rows x 2 columns]

# %%
train_02=train_02.drop('id',axis=1)

# %%
train_02.replace("[^a-zA-Z]"," ",regex=True,inplace=True)

# %%
test_02=test_02.drop('id',axis=1)

# %%
test_02.replace("[^a-zA-Z]"," ",regex=True,inplace=True)

# %%
test_02
# Out:
#                                                    clean
# 0                                             to find
# 1      want everyone to see the new            and he...
# 2                               safe ways to heal your
# 3      is the hp and the cursed child book up for res...
# 4      rd to my amazing hilarious eli ahmir uncle dav...
# 5                                           choose to be
# 6      something inside me dies             eyes ness
# 7
# 8      i will never understand why my dad left me whe...
# 9                                        mannaepicure
# 10     dayswasted   narcosis infinite ep make me awar...
# 11              one of the worlds greatest spoing events
# 12             half way through the website now and very
# 13     good food good life  and                      ...
# 14                                 ill stand behind this
# 15                          i atei ate and i ate
# 16       got my limited edition rain or shine set today
# 17                    amp  amp  amp too how to keep your
# 18                                 london united kingdom
# 19     thought factory bbc neutrality on right wing f...
# 20     hey guys tommorow is the last day of my exams ...
# 21                           memories
# 22     my mind is like                  but my body l...
# 23      never been this down on myself in my entire life
# 24     check twitterww   trends trending worldwide   ...
# 25                         i thought i saw a mermaid
# 26                  chick gets fucked hottest naked lady
# 27                          happy bday lucy
# 28     haroldfriday have a weekend filled with sunbea...
# 29     tried that but nothing   will try again know y...
# ...                                                  ...
# 17167  people do anything for fucking attention nowad...
# 17168  creative bubble got burst      looking forward...
# 17169  tomorrow is gonna be a big day we are going to...
# 17170                     i am thankful for baby giggles
# 17171  i love u take with u all the time in ur       ...
# 17172  in life u will grow to learn some pple will wo...
# 17173      i was the stormyou were the rain together ...
# 17174                            lovelgq   broken ep via
# 17175      spread love not hate
# 17176                       are the most racist pay ever
# 17177                         i am thankful for children
# 17178                        liverpool
# 17179  rooster simulation i want to climb the vast ea...
# 17180                             por do sol
# 17181  hell yeah what a great surprise for your prese...
# 17182  when ur the joke ur defensive towards everythi...
# 17183                      the in my     evening
# 17184  tonight on from pm gmt you can here a special ...
# 17185                  today is a good day for excercise
# 17186  good night with a tea and music               ...
# 17187  loving life                   hyatt regency lo...
# 17188  black professor demonizes proposes nazi style ...
# 17189                        learn how to think positive
# 17190             we love the pretty happy and fresh you
# 17191   damn tuff ruff muff  techno city ng    web   ...
# 17192       thought factory left right polarisation  gt
# 17193                    feeling like a mermaid
# 17194  today in omg  amp used words like assets ampli...
# 17195  happy at work conference right mindset leads t...
# 17196                      my song so glad free download
#
# [17197 rows x 1 columns]

# %%
id=test.pop('id')

# %%
id.shape
# Out:
# (17197,)

# %%
#def combine():
    
    #combined=train_02.append(test_02)
    #combined.reset_index(inplace=True)
    #return combined

# %%
#combined=combine()

# %%
#combined.shape
#combined.drop('index',axis=1,inplace=True)

# %%
#combined
# Out:
#                                                    clean
# 0      when a father is dysfunctional and is so selfi...
# 1      thanks for credit i cant use cause they dont o...
# 2                                    bihday your majesty
# 3      i love u take with u all the time in ur       ...
# 4                                 factsguide society now
# 5          huge fan fare and big talking before they ...
# 6                              camping tomorrow danny
# 7      the next school year is the year for exams    ...
# 8                               we won love the land
# 9                               welcome here  im its so
# 10         consumer price index mom climbed from prev...
# 11                                     we are so selfish
# 12                           i get to see my daddy today
# 13             calls middle school build the wall chant
# 14                                         no comment in
# 15                               ouchjunior is angry
# 16                      i am thankful for having a paner
# 17                                  retweet if you agree
# 18     its       smiles all around via ig user make p...
# 19     as we all know essential oils are not made of ...
# 20     people blaming ha for conceded goal was it fat...
# 21                                       sad little dude
# 22     product of the day happy man tool whos its the...
# 23                     lumpy says i am a  prove it lumpy
# 24                                                to my
# 25                     beautiful sign by vendor for
# 26     all when is           in  sunday love         ...
# 27     we had a great panel on the mediatization of t...
# 28                    happy fathers day
# 29     people went to nightclub to have a good night ...
# ...                                                  ...
# 49129  people do anything for fucking attention nowad...
# 49130  creative bubble got burst      looking forward...
# 49131  tomorrow is gonna be a big day we are going to...
# 49132                     i am thankful for baby giggles
# 49133  i love u take with u all the time in ur       ...
# 49134  in life u will grow to learn some pple will wo...
# 49135      i was the stormyou were the rain together ...
# 49136                            lovelgq   broken ep via
# 49137      spread love not hate
# 49138                       are the most racist pay ever
# 49139                         i am thankful for children
# 49140                        liverpool
# 49141  rooster simulation i want to climb the vast ea...
# 49142                             por do sol
# 49143  hell yeah what a great surprise for your prese...
# 49144  when ur the joke ur defensive towards everythi...
# 49145                      the in my     evening
# 49146  tonight on from pm gmt you can here a special ...
# 49147                  today is a good day for excercise
# 49148  good night with a tea and music               ...
# 49149  loving life                   hyatt regency lo...
# 49150  black professor demonizes proposes nazi style ...
# 49151                        learn how to think positive
# 49152             we love the pretty happy and fresh you
# 49153   damn tuff ruff muff  techno city ng    web   ...
# 49154       thought factory left right polarisation  gt
# 49155                    feeling like a mermaid
# 49156  today in omg  amp used words like assets ampli...
# 49157  happy at work conference right mindset leads t...
# 49158                      my song so glad free download
#
# [49159 rows x 1 columns]

# %%
#train['clean'].head()
# Out:
# 0    when a father is dysfunctional and is so selfi...
# 1    thanks for credit i cant use cause they dont o...
# 2                                  bihday your majesty
# 3    i love u take with u all the time in urð± ð...
# 4                               factsguide society now
# Name: clean, dtype: object

# %%
#separating the train data set into inputs and targets
#x = train['clean']
#y = train['label']
x=train_02['clean']
y=label

# %%
todo=test_02['clean']

# %%
combined.shape
# Out:
# (49159, 1)

# %%
#vectorize tweets using countvectorize
vectorizer = CountVectorizer(binary=True, stop_words = 'english',max_features = 15000)
#creating vectormatrix 
x_vec = vectorizer.fit_transform(x)
#vec=vectorizer.fit_transform(combined)

# %%
#vec
# Out:
# <1x1 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
x_vec
# Out:
# <31962x15000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 147167 stored elements in Compressed Sparse Row format>

# %%
print(vectorizer.get_feature_names())
# Out:
# ['aa', 'aaa', 'aaberg', 'aap', 'aaron', 'ab', 'abandoned', 'abba', 'abbyybelle', 'abc', 'abe', 'abetting', 'ability', 'able', 'abo', 'aboion', 'abomination', 'abraham', 'abroad', 'abs', 'absence', 'absolute', 'absolutely', 'absolutes', 'abstract', 'absurd', 'abt', 'abu', 'abuja', 'abuse', 'abusive', 'ac', 'academy', 'acc', 'accent', 'accept', 'acceptable', 'acceptance', 'accepted', 'accepting', 'access', 'acc
', 'amrica', 'amsterdam', 'amused', 'amy', 'ana', 'anal', 'analysis', 'analytics', 'analyzing', 'anc', 'anchor', 'anchored', 'ancient', 'andaelentari', 'anderson', 'andrea', 'andreas', 'andrew', 'android', 'andy', 'anf', 'anfield', 'angel', 'angela', 'angeles', 'angelic', 'angelou', 'angels', 'anger', 'angie', 'angry', 'angst', 'anguish', 'angus', 'animal', 'animaladvocate', 'animals', 'animated', 'animation', 'anime', 'aniston', 'ankara', 'anna', 'anne', 'anniversaries', 'anniversary', 'announce', 'announced', 'announcement', 'announcements', 'announcers', 'announces', 'annoy', 'annoyed', 'annoying', 'annual', 'anon', 'anonymous', 'answer', 'answered', 'answers', 'antagonizing', 'antaica', 'an ...

# %%
#train_03=vec[:31962,]
#test_03=vec[31962:,]

# %%
#spliting the train data for train and test split cross validation
#X_train, X_test, Y_train, Y_test = train_test_split(vec,label,stratify=label,test_size=0.3,random_state=2,shuffle=True)

# %%
#spliting the train data for train and test split cross validation
x_train, x_test, y_train, y_test = train_test_split(x_vec,y,stratify=y,test_size=0.3,random_state=2,shuffle=True)

# %%
#build model
#linear svm model
svm = svm.SVC(kernel='linear', probability = True)

# %%
model_1= svm.fit(x_vec,y)

# %%
x_vec_test = vectorizer.fit_transform(test_02['clean'])

# %%
x_vec_test
# Out:
# <17197x15000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 82099 stored elements in Compressed Sparse Row format>

# %%
pred_test=model_1.predict(x_vec_test)

# %%
pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#f1 score
from sklearn.metrics import f1_score

from sklearn.metrics import confusion_matrix

print("F1 score :", f1_score(y_test,y_pred ))
# Out:
# F1 score : 0.5691489361702128

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[8782,  134],
#        [ 352,  321]])

# %%
prob = svm.fit(x_train, y_train)

# %%
y_pred = svm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 94.93169256439671

# %%
#creating output file
test_pred = svm.predict()


#output
pred=svm.predict(todo)

#my_submission = pd.DataFrame({'ID':test.id ,'label': pred})
#my_submission.to_csv('submission_1.csv', index=False)

# %%
my_submission = pd.DataFrame({'id':id,'label': pred_test})
my_submission.to_csv('twitter_2.csv', index=False)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages (1.3.3)
# Requirement already satisfied: numpy in /Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.19.2)
# Requirement already satisfied: scipy in /Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.5.2)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Users/lakshmipriya/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from xgboost import XGBClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-149-477fa34615c5> in <module>
# ----> 1 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
model_xgb= XGBClassifier()
model_xgb.fit(x_train, y_train)

y_pred_xgb = model.predict(x_test)

print("Training Accuracy :", model_xgb.score(x_train, y_train))
print("Validation Accuracy :", model_xgb.score(x_test, y_test))

# calculating the f1 score for the validation set
print("f1 score :", f1_score(y_test, y_pred))

# confusion matrix
cm_1 = confusion_matrix(y_valid, y_pred_xgb)
print(cm_1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-145-f29bde96be8d> in <module>
# ----> 1 from xgboost import XGBClassifier
#       2
#       3 model_xgb= XGBClassifier()
#       4 model_xgb.fit(x_train, y_train)
#       5
#
# ModuleNotFoundError: No module named 'xgboost'
